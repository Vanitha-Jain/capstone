# %% [markdown]
# <a href="https://colab.research.google.com/github/Vanitha-Jain/capstone/blob/Combined-code/Test_combined.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
print(os.listdir("/content"))
# Out:
# ['.config', 'Testset1_AtomPairCount2D_after_feature.csv', 'Testset1_KleKotaRoth_after_feature.csv', 'Testset1_CDK_after_feature.csv', 'Testset1_CDKG_after_feature.csv', 'Testset1_Estate_after_feature.csv', 'Testset1_CDKE_after_feature.csv', 'Testset1_AtomPair2D_after_feature.csv', 'Testset1_MorganFP_after_feature.csv', 'Testset1_Substructure_after_feature.csv', 'Testset1_MACCS_after_feature.csv', 'Testset1_Pubchem_after_feature.csv', 'Testset1_RDKit_after_feature.csv', 'Testset1_KleKotaRothCount_after_feature.csv', 'Testset1_SubstructureCount_after_feature.csv', 'sample_data']

# %%
import pandas as pd

# Define the list of file paths for all 14 CSV files
file_paths = [
     'Testset1_AtomPairCount2D_after_feature.csv', 'Testset1_KleKotaRoth_after_feature.csv', 'Testset1_CDK_after_feature.csv', 'Testset1_CDKG_after_feature.csv', 'Testset1_Estate_after_feature.csv', 'Testset1_CDKE_after_feature.csv', 'Testset1_AtomPair2D_after_feature.csv', 'Testset1_MorganFP_after_feature.csv', 'Testset1_Substructure_after_feature.csv', 'Testset1_MACCS_after_feature.csv', 'Testset1_Pubchem_after_feature.csv', 'Testset1_RDKit_after_feature.csv', 'Testset1_KleKotaRothCount_after_feature.csv', 'Testset1_SubstructureCount_after_feature.csv'
]

# Read the first dataset to initialize
df_combined = pd.read_csv(file_paths[0])

# Check if "Unnamed: 0" and "bioactivity_class" columns are the same across all datasets
for file_path in file_paths[1:]:
    df = pd.read_csv(file_path)

    # Check if 'Unnamed: 0' and 'bioactivity_class' columns are equal to the first dataset
    if not df['Unnamed: 0'].equals(df_combined['Unnamed: 0']) or not df['class'].equals(df_combined['class']):
        raise ValueError(f"Mismatch in columns 'Unnamed: 0' or 'class' in file {file_path}")

# Now append the remaining datasets, keeping the column order as they are
for file_path in file_paths[1:]:
    df = pd.read_csv(file_path)

    # Merge on 'Unnamed: 0' and 'bioactivity_class', but keep the rest of the columns as they are
    df_combined = pd.merge(df_combined, df, on=['Unnamed: 0', 'class'], how='outer')

# Save the combined dataframe to a new CSV file
df_combined.to_csv("combined_dataset_fs.csv", index=False)

print("Datasets combined successfully!")
# Out:
# Datasets combined successfully!
