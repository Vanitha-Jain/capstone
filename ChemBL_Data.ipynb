# %% [markdown]
# <a href="https://colab.research.google.com/github/Vanitha-Jain/capstone/blob/Data-Collection/ChemBL_Data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! pip install chembl_webresource_client
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.2/55.2 kB 2.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.4/61.4 kB 4.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.4/66.4 kB 4.7 MB/s eta 0:00:00
# ...

# %%
import pandas as pd
from chembl_webresource_client.new_client import new_client

# %%
target = new_client.target
target_query = target.search('Huh-7')
targets = pd.DataFrame.from_dict(target_query)
targets
# Out:
#     cross_references                                         organism  \
# 0                 []                                     Homo sapiens
# 1                 []                                     Homo sapiens
# 2                 []                                     Homo sapiens
# 3                 []                                     Mus musculus
# 4                 []                                Rattus norvegicus
# ..               ...                                              ...
# 379               []  Severe acute respiratory syndrome coronavirus 2
# 380               []                                     Homo sapiens
# 381               []                                Rattus norvegicus
# 382               []                                     Homo sapiens
# 383               []                                     Homo sapiens
#
#                            pref_name  score  species_group_flag  \
# ...

# %%
selected_target = targets.target_chembl_id[0]
selected_target
# Out:
# 'CHEMBL614039'

# %%
activity = new_client.activity
res = activity.filter(target_chembl_id=selected_target).filter(standard_type="IC50")

# %%
df = pd.DataFrame.from_dict(res)

# %%
df.head()
# Out:
#   action_type activity_comment  activity_id activity_properties  \
# 0        None             None       108394                  []
# 1        None             None       121355                  []
# 2        None             None       125130                  []
# 3        None             None       126550                  []
# 4        None             None       128985                  []
#
#   assay_chembl_id                                  assay_description  \
# 0    CHEMBL697950  Inhibitory concentration against Huh-7 human h...
# 1    CHEMBL697950  Inhibitory concentration against Huh-7 human h...
# 2    CHEMBL697950  Inhibitory concentration against Huh-7 human h...
# 3    CHEMBL697950  Inhibitory concentration against Huh-7 human h...
# 4    CHEMBL697950  Inhibitory concentration against Huh-7 human h...
#
#   assay_type assay_variant_accession assay_variant_mutation bao_endpoint  ...  \
# 0          F                    None                   None  BAO_0000190  ...
# ...

# %%
df.standard_type.unique()
# Out:
# array(['IC50'], dtype=object)

# %%
df.to_csv('bioactivity_data.csv', index=False)

# %%
print("\nMissing Values per Column:")
print(df.isnull().sum())
# Out:
# Missing Values per Column:
# action_type                  1881
# activity_comment             1815
# activity_id                     0
# activity_properties             0
# assay_chembl_id                 0
# assay_description               0
# assay_type                      0
# assay_variant_accession      1881
# assay_variant_mutation       1881
# bao_endpoint                    0
# bao_format                      0
# bao_label                       0
# canonical_smiles                1
# data_validity_comment        1816
# data_validity_description    1816
# document_chembl_id              0
# document_journal              100
# document_year                  99
# ligand_efficiency            1881
# molecule_chembl_id              0
# molecule_pref_name           1626
# parent_molecule_chembl_id       0
# pchembl_value                 535
# potential_duplicate             0
# qudt_units                     63
# record_id                       0
# ...

# %%
df_cleaned = df.dropna()

# %%
print("\nNumber of Duplicate Rows:", df_cleaned.duplicated().sum())
# Out:
# Number of Duplicate Rows: 0

# %%
df = df[df.standard_value.notna()]
df
# Out:
#      action_type activity_comment  activity_id  \
# 0           None             None       108394
# 1           None             None       121355
# 2           None             None       125130
# 3           None             None       126550
# 4           None             None       128985
# ...          ...              ...          ...
# 1876        None             None     25653155
# 1877        None             None     25653156
# 1878        None             None     25653157
# 1879        None             None     25653158
# 1880        None             None     25653159
#
#                                     activity_properties assay_chembl_id  \
# 0                                                    []    CHEMBL697950
# 1                                                    []    CHEMBL697950
# 2                                                    []    CHEMBL697950
# 3                                                    []    CHEMBL697950
# ...

# %%
bioactivity_class = []
for i in df.standard_value:
  if float(i) >= 10000:
    bioactivity_class.append("inactive")
  elif float(i) <= 1000:
    bioactivity_class.append("active")
  else:
    bioactivity_class.append("intermediate")

# %%
mol_cid = []
for i in df.molecule_chembl_id:
  mol_cid.append(i)

# %%
canonical_smiles = []
for i in df.canonical_smiles:
  canonical_smiles.append(i)

# %%
standard_value = []
for i in df.standard_value:
  standard_value.append(i)

# %%
data_tuples = list(zip(mol_cid, canonical_smiles, bioactivity_class, standard_value))
df = pd.DataFrame( data_tuples,  columns=['molecule_chembl_id', 'canonical_smiles', 'bioactivity_class', 'standard_value'])

# %%
df
# Out:
#      molecule_chembl_id                                   canonical_smiles  \
# 0          CHEMBL167155  CC(=O)c1ccc(-c2cc(NS(=O)(=O)c3ccccc3C)c(C(=O)O...
# 1          CHEMBL166740  Cc1ccccc1S(=O)(=O)Nc1cc(-c2ccc(S(C)(=O)=O)cc2)...
# 2          CHEMBL165038  Cc1cc(S(=O)(=O)Nc2cc(-c3ccccc3)sc2C(=O)O)c(C)c...
# 3          CHEMBL435857    Cc1cc(Cl)ccc1S(=O)(=O)Nc1cc(-c2ccccc2)sc1C(=O)O
# 4          CHEMBL352783      Cc1cccc(S(=O)(=O)Nc2cc(-c3ccccc3)sc2C(=O)O)c1
# ...                 ...                                                ...
# 1810      CHEMBL5405698                     C#Cc1ccccc1/C=C/c1nccc2ccccc12
# 1811      CHEMBL5416562           C(=C/c1nccc2ccccc12)\c1ccc(-c2ccccc2)cc1
# 1812          CHEMBL165                     Oc1ccc(/C=C/c2cc(O)cc(O)c2)cc1
# 1813          CHEMBL185                            O=c1[nH]cc(F)c(=O)[nH]1
# 1814         CHEMBL1336  CNC(=O)c1cc(Oc2ccc(NC(=O)Nc3ccc(Cl)c(C(F)(F)F)...
#
#      bioactivity_class standard_value
# ...

# %%
df.to_csv('bioactivity_preprocessed_data.csv', index=False)
